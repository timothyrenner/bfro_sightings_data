# %%
import polars as pl
import datapane as dp
import altair as alt

# %%
reports = pl.scan_csv("../pipeline/data/processed/bfro_reports_geocoded.csv")

# %%
reports.head().collect()
# Out:
# shape: (5, 29)
# ┌───────────┬────────────┬───────────┬───────────┬───┬──────────┬──────────┬────────────┬──────────┐
# │ observed  ┆ location_d ┆ county    ┆ state     ┆ … ┆ uv_index ┆ visibili ┆ wind_beari ┆ wind_spe │
# │ ---       ┆ etails     ┆ ---       ┆ ---       ┆   ┆ ---      ┆ ty       ┆ ng         ┆ ed       │
# │ str       ┆ ---        ┆ str       ┆ str       ┆   ┆ f64      ┆ ---      ┆ ---        ┆ ---      │
# │           ┆ str        ┆           ┆           ┆   ┆          ┆ f64      ┆ f64        ┆ f64      │
# ╞═══════════╪════════════╪═══════════╪═══════════╪═══╪══════════╪══════════╪════════════╪══════════╡
# │ hello.    ┆ Off of rt  ┆ Ohio      ┆ West      ┆ … ┆ null     ┆ 9.1      ┆ 231.4      ┆ 18.3     │
# │ some time ┆ 2 in       ┆ County    ┆ Virginia  ┆   ┆          ┆          ┆            ┆          │
# │ back i    ┆ warwood.   ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ submitte… ┆            ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ I may     ┆ The place  ┆ Grant     ┆ Oregon    ┆ … ┆ null     ┆ 20.1     ┆ 42.6       ┆ 8.1      │
# │ have      ┆ we camped  ┆ County    ┆           ┆   ┆          ┆          ┆            ┆          │
# │ already   ┆ was just   ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ given     ┆ off…       ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ this en…  ┆            ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ My        ┆ There is a ┆ Coffey    ┆ Kansas    ┆ … ┆ null     ┆ 5.5      ┆ 159.7      ┆ 17.2     │
# │ husband   ┆ backroad   ┆ County    ┆           ┆   ┆          ┆          ┆            ┆          │
# │ and 2     ┆ after      ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ sons and  ┆ passin…    ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ I live…   ┆            ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ I live in ┆ we are off ┆ Henderson ┆ Tennessee ┆ … ┆ null     ┆ 5.9      ┆ 312.4      ┆ 18.3     │
# │ henderson ┆ of highway ┆ County    ┆           ┆   ┆          ┆          ┆            ┆          │
# │ county in ┆ 40         ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ we…       ┆            ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ Around    ┆ Longitude- ┆ Jasper    ┆ Illinois  ┆ … ┆ null     ┆ 7.7      ┆ 186.1      ┆ 21.9     │
# │ five      ┆ 87.97622   ┆ County    ┆           ┆   ┆          ┆          ┆            ┆          │
# │ years ago ┆ Lattitude- ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ me and a  ┆ 38.…       ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# │ b…        ┆            ┆           ┆           ┆   ┆          ┆          ┆            ┆          │
# └───────────┴────────────┴───────────┴───────────┴───┴──────────┴──────────┴────────────┴──────────┘

# %%
report_classifications = reports.groupby("classification").count().collect()
report_classifications
# Out:
# shape: (3, 2)
# ┌────────────────┬───────┐
# │ classification ┆ count │
# │ ---            ┆ ---   │
# │ str            ┆ u32   │
# ╞════════════════╪═══════╡
# │ Class A        ┆ 2579  │
# │ Class C        ┆ 33    │
# │ Class B        ┆ 2668  │
# └────────────────┴───────┘

# %%
from typing import Dict
classification_numbers: Dict[str, dp.BigNumber] = {}
for classification, count in report_classifications.iter_rows():
     classification_numbers[classification] = dp.BigNumber(
         heading=f"Number of {classification} Sightings",
         value=count
     )

# %%
report_classification_group = dp.Group(
    dp.Text("# Report Classifications"),
    dp.Group(
        classification_numbers["Class A"],
        classification_numbers["Class B"],
        classification_numbers["Class C"],
        dp.Text("""
        Class A reports involve clear sightings in circumstances where misinterpretation or misidentification of other animals can be ruled out with greater confidence.
        """),
        dp.Text("""
        Incidents where a possible sasquatch was observed at a great distance or in poor lighting conditions and incidents in any other circumstance that did not afford a clear view of the subject are considered Class B reports.
        """),
        dp.Text("""
        Most second-hand reports, and any third-hand reports, or stories with an untraceable sources, are considered Class C, because of the high potential for inaccuracy.
        """),
        columns=3
    ),
    columns=1
)

report_classification_group
# Out:
# <style>
#   #dp-fdb1c4441b37484c9069e07c9e0ba6a9 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="dp-fdb1c4441b37484c9069e07c9e0ba6a9" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link rel=&quot;shortcut icon&quot; type=&quot;image/png&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;shortcut icon&quot; sizes=&quot;192x192&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;apple-touch-icon&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
#
# &lt;script src=&quot;https://kit.fontawesome.com/256c714d9a.js&quot;&gt;&lt;/script&gt;
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.5/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.5/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   // analytics config
#   // TODO -- pass these in as props for consistency?
#   window.dpAppRunner = &quot;False&quot; === &quot;True&quot;;
#   window.dpLocal = true;
#     window.dpLocalViewEvent = true;
#     window.dpReportId = &quot;fdb1c4441b37484c9069e07c9e0ba6a9&quot;;
#     window.dpAuthorId = &quot;82e136cb011f497b92dc952ca437c34d&quot;;
#
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: left;
#     --dp-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#
#   if (!window.dpAppRunner) {
#       // pass app data via props if in local (static) mode, otherwise this data is fetched from the server
#       window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cGroup columns=\&quot;1\&quot; valign=\&quot;top\&quot;\u003e\u003cText\u003e\u003c![CDATA[# Report Classifications]]\u003e\u003c/Text\u003e\u003cGroup columns=\&quot;3\&quot; valign=\&quot;top\&quot;\u003e\u003cBigNumber heading=\&quot;Number of Class A Sightings\&quot; value=\&quot;2579\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003cBigNumber heading=\&quot;Number of Class B Sightings\&quot; value=\&quot;2668\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003cBigNumber heading=\&quot;Number of Class C Sightings\&quot; value=\&quot;33\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003cText\u003e\u003c![CDATA[Class A reports involve clear sightings in circumstances where misinterpretation or misidentification of other animals can be ruled out with greater confidence.]]\u003e\u003c/Text\u003e\u003cText\u003e\u003c![CDATA[Incidents where a possible sasquatch was observed at a great distance or in poor lighting conditions and incidents in any other circumstance that did not afford a clear view of the subject are considered Class B reports.]]\u003e\u003c/Text\u003e\u003cText\u003e\u003c![CDATA[Most second-hand reports, and any third-hand reports, or stories with an untraceable sources, are considered Class C, because of the high potential for inaccuracy.]]\u003e\u003c/Text\u003e\u003c/Group\u003e\u003c/Group\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {}} }};
#   }
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://datapane-cdn.com/v0.16.5/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://datapane-cdn.com/v0.16.5/assets/iframeResizer.contentWindow.min.js&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://datapane-cdn.com/v0.16.5/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#dp-fdb1c4441b37484c9069e07c9e0ba6a9");
# </script>

# %%
from vega_datasets import data
states = alt.topo_feature(data.us_10m.url, feature="states")
background = alt.Chart(
    states
).mark_geoshape(
    fill="lightgray",
    stroke="white"
).project("albersUsa")

# lat_min / lat_max / lon_min / lon_max
# USA	United States	24.9493	49.5904	-125.0011	-66.9326

report_locations = reports.filter(
    pl.col("state").is_not_null() &
    pl.col("latitude").is_not_null() &
    pl.col("longitude").is_not_null() &
    (
        (
            # continental us
            (pl.col("latitude") > 24.943) &
            (pl.col("latitude") < 49.5904) &
            (pl.col("longitude") > -125.0011) &
            (pl.col("longitude") < -66.9326)
        ) |
        # or AK/HI
        (pl.col("state") == "Hawaii") |
        (pl.col("state") == "Alaska")
    )
).select(
    pl.col("latitude"),
    pl.col("longitude"),
    pl.col("classification")
).collect().to_pandas()

points = alt.Chart(report_locations).mark_circle(
    size=10,
).encode(
    longitude="longitude:Q", 
    latitude="latitude:Q",
    color=alt.Color("classification:N", title="Classification")
)

bfro_map = (background + points).properties(
    title="Bigfoot Sightings"
)

# bfro_map

# %%
reports_per_year = reports.filter(
    pl.col("date").str.contains("\d{4}-\d{2}-\d{2}")
).with_columns(
    sighting_year=pl.col("date").str.to_datetime("%Y-%m-%d").dt.year()
).groupby(
    "sighting_year",
    "classification"
).count().filter(
    pl.col("sighting_year") >= 2003
).collect()

reports_per_year_chart = alt.Chart(
    reports_per_year.to_pandas()
).mark_bar().encode(
    x=alt.X("sighting_year:O", title="Year"),
    y=alt.Y("count:Q", title="Number of Sightings"),
    color=alt.Color("classification:N", title="Classification"),
    tooltip=alt.Tooltip("count:Q")
).properties(
    title="Sightings by Year"
)

reports_per_year_chart
# Out:
# alt.Chart(...)

# %%
sightings_by_state = (
    reports
    .filter(pl.col("state").is_not_null())
    .groupby("state", "classification")
    .count()
    .sort(by="count", descending=True)
    .collect()
)


sightings_by_state_chart = (
    alt.Chart(sightings_by_state.to_pandas())
    .mark_bar()
    .encode(
        x=alt.X("state:N", title="State", sort="-y"),
        y=alt.Y("count:Q", title="Number of Sightings"),
        color=alt.Color("classification:N", title="Classification"),
        tooltip=alt.Tooltip("count:Q")
    )
    .properties(
        title="Sightings by State"
    )
)

sightings_by_state_chart
# Out:
# alt.Chart(...)

# %%
report_seasons = (
    reports
    .filter(pl.col("season").is_not_null())
    .groupby("season")
    .count()
    .collect()
)

report_seasons_dict: Dict[str, dp.BigNumber] = dict()

for season, count in report_seasons.iter_rows():
    report_seasons_dict[season] = dp.BigNumber(
        value=count,
        heading=f"Sightings in {season}"
    )

report_seasons_group = dp.Group(
    dp.Text("# Sightings by Season"),
    dp.Group(
        report_seasons_dict["Spring"],
        report_seasons_dict["Summer"],
        report_seasons_dict["Fall"],
        report_seasons_dict["Winter"],
        columns=4
    ),
    dp.Text(
        """
        Sightings are significantly higher in the summer and fall.
        This could be due to more daylight hours or friendlier temperatures in places 
        with higher sightings overall. Either way, it makes sense that there are more 
        reported sightings when the weather is nice, because people are more likely to 
        be outside.
        """
    ),
    columns=1
)

report_seasons_group
# Out:
# <style>
#   #dp-91c7fd27eaaa48c6870eaa38cdd083b5 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="dp-91c7fd27eaaa48c6870eaa38cdd083b5" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link rel=&quot;shortcut icon&quot; type=&quot;image/png&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;shortcut icon&quot; sizes=&quot;192x192&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;apple-touch-icon&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
#
# &lt;script src=&quot;https://kit.fontawesome.com/256c714d9a.js&quot;&gt;&lt;/script&gt;
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.5/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.5/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   // analytics config
#   // TODO -- pass these in as props for consistency?
#   window.dpAppRunner = &quot;False&quot; === &quot;True&quot;;
#   window.dpLocal = true;
#     window.dpLocalViewEvent = true;
#     window.dpReportId = &quot;91c7fd27eaaa48c6870eaa38cdd083b5&quot;;
#     window.dpAuthorId = &quot;82e136cb011f497b92dc952ca437c34d&quot;;
#
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: left;
#     --dp-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#
#   if (!window.dpAppRunner) {
#       // pass app data via props if in local (static) mode, otherwise this data is fetched from the server
#       window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cGroup columns=\&quot;1\&quot; valign=\&quot;top\&quot;\u003e\u003cText\u003e\u003c![CDATA[# Sightings by Season]]\u003e\u003c/Text\u003e\u003cGroup columns=\&quot;4\&quot; valign=\&quot;top\&quot;\u003e\u003cBigNumber heading=\&quot;Sightings in Spring\&quot; value=\&quot;831\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003cBigNumber heading=\&quot;Sightings in Summer\&quot; value=\&quot;1894\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003cBigNumber heading=\&quot;Sightings in Fall\&quot; value=\&quot;1508\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003cBigNumber heading=\&quot;Sightings in Winter\&quot; value=\&quot;760\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003c/Group\u003e\u003cText\u003e\u003c![CDATA[Sightings are significantly higher in the summer and fall.\nThis could be due to more daylight hours or friendlier temperatures in places \nwith higher sightings overall. Either way, it makes sense that there are more \nreported sightings when the weather is nice, because people are more likely to \nbe outside.]]\u003e\u003c/Text\u003e\u003c/Group\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {}} }};
#   }
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://datapane-cdn.com/v0.16.5/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://datapane-cdn.com/v0.16.5/assets/iframeResizer.contentWindow.min.js&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://datapane-cdn.com/v0.16.5/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#dp-91c7fd27eaaa48c6870eaa38cdd083b5");
# </script>

# %%
(
    reports
    .select(
        pl.col("temperature_mid"),
        pl.col("humidity"),
        pl.col("cloud_cover"),
        pl.col("precip_intensity"),
        pl.col("visibility"),
        pl.col("pressure")
    )
    .collect()
    .describe()
)
# Out:
# shape: (9, 7)
# ┌────────────┬────────────────┬───────────┬─────────────┬───────────────┬────────────┬─────────────┐
# │ describe   ┆ temperature_mi ┆ humidity  ┆ cloud_cover ┆ precip_intens ┆ visibility ┆ pressure    │
# │ ---        ┆ d              ┆ ---       ┆ ---         ┆ ity           ┆ ---        ┆ ---         │
# │ str        ┆ ---            ┆ f64       ┆ f64         ┆ ---           ┆ f64        ┆ f64         │
# │            ┆ f64            ┆           ┆             ┆ f64           ┆            ┆             │
# ╞════════════╪════════════════╪═══════════╪═════════════╪═══════════════╪════════════╪═════════════╡
# │ count      ┆ 5280.0         ┆ 5280.0    ┆ 5280.0      ┆ 5280.0        ┆ 5280.0     ┆ 5280.0      │
# │ null_count ┆ 1270.0         ┆ 1283.0    ┆ 1315.0      ┆ 1702.0        ┆ 1338.0     ┆ 1554.0      │
# │ mean       ┆ 58.012219      ┆ 68.593195 ┆ 45.889206   ┆ 0.094409      ┆ 10.509614  ┆ 1016.938701 │
# │ std        ┆ 16.634994      ┆ 15.686753 ┆ 32.904563   ┆ 0.307969      ┆ 5.84781    ┆ 6.146392    │
# │ min        ┆ -19.5          ┆ 7.8       ┆ 0.0         ┆ 0.0           ┆ 0.0        ┆ 980.4       │
# │ max        ┆ 96.1           ┆ 100.0     ┆ 100.0       ┆ 7.468         ┆ 74.6       ┆ 1045.1      │
# │ median     ┆ 59.85          ┆ 70.9      ┆ 43.6        ┆ 0.0           ┆ 9.7        ┆ 1016.8      │
# │ 25%        ┆ 47.2           ┆ 59.8      ┆ 15.6        ┆ 0.0           ┆ 8.2        ┆ 1013.2      │
# │ 75%        ┆ 70.9           ┆ 79.8      ┆ 75.0        ┆ 0.035         ┆ 9.9        ┆ 1020.5      │
# └────────────┴────────────────┴───────────┴─────────────┴───────────────┴────────────┴─────────────┘

# %% [markdown]
# * temperature_mid ranges -19.5 to 96.1
# * humidity ranges 7.8 to 100
# * cloud cover ranges 0 to 100
# * precip intensity ranges 0 to 7.468
# * visibility ranges from 0 to 74.6
# * pressure ranges from 980.4 to 1045.1

# %%
from typing import List, Optional
def add_bins(frame: pl.DataFrame, column: str, bins: List) -> pl.DataFrame:
    """ Adds the bin boundaries to the provided data frame, as
    a convenience for creating histograms.
    """
    cut_results = frame[column].cut(bins=bins, maintain_order=True)
    return frame.with_columns(
        cut_results["break_point"].alias(f"{column}_binned")
    )

def make_sighting_histogram_chart(
    frame: pl.LazyFrame,
    bins: List,
    column: str,
    title: Optional[str] = None
) -> alt.Chart:
    if title is None:
        title = column.title()
    
    frame_for_bins = (
        frame
        .filter(pl.col(column).is_not_null())
        .select(pl.col(column), pl.col("classification"))
        .collect()
    )
    
    frame_with_bins = add_bins(frame_for_bins, column, bins)
    
    frame_histogram = (
        frame_with_bins
        .groupby(f"{column}_binned", "classification")
        .count()
    )
    
    frame_histogram_chart = (
        alt.Chart(frame_histogram.to_pandas())
        .mark_bar()
        .encode(
            x=alt.X(f"{column}_binned:N", title=title),
            y=alt.Y("count:Q", title="Number of Sightings"),
            color=alt.Color("classification:N", title="Classification"),
            tooltip=alt.Tooltip("count:Q")
        )
        .properties(
            title=f"Sightings by {title}",
            width=alt.Step(50)
        )
    )
    
    return frame_histogram_chart

# %%
temperature_bins = list(range(-20, 101, 10))
temperature_histogram_chart = make_sighting_histogram_chart(
    reports,
    temperature_bins,
    "temperature_mid",
    title="Temperature"
)

temperature_histogram_chart
# Out:
# alt.Chart(...)

# %%
humidity_bins = list(range(0,101,10))
humidity_histogram_chart = make_sighting_histogram_chart(
    reports,
    humidity_bins,
    "humidity"
)

humidity_histogram_chart
# Out:
# alt.Chart(...)

# %%
cloud_cover_bins = list(range(0,101,10))
cloud_cover_histogram_chart = make_sighting_histogram_chart(
    reports,
    cloud_cover_bins,
    "cloud_cover",
    "Cloud Cover"
)

cloud_cover_histogram_chart
# Out:
# alt.Chart(...)

# %%
import numpy as np
precip_intensity_bins = np.arange(0.0, 8.25, 0.75).tolist()
precip_intensity_histogram_chart = make_sighting_histogram_chart(
    reports,
    precip_intensity_bins,
    "precip_intensity",
    title="Precipitation"
)
precip_intensity_histogram_chart
# Out:
# alt.Chart(...)

# %%
visibility_bins = np.arange(0.0, 82.5, 7.5)
visibility_histogram_chart = make_sighting_histogram_chart(
    reports,
    visibility_bins,
    "visibility",
    title="Visibility"
)
visibility_histogram_chart
# Out:
# alt.Chart(...)

# %%
pressure_bins = np.arange(980, 1060, 6.5).tolist()
pressure_histogram_chart = make_sighting_histogram_chart(
    reports,
    pressure_bins,
    "pressure"
)
pressure_histogram_chart
# Out:
# alt.Chart(...)

# %%
weather_group = dp.Group(
    temperature_histogram_chart,
    humidity_histogram_chart,
    cloud_cover_histogram_chart,
    precip_intensity_histogram_chart,
    visibility_histogram_chart,
    pressure_histogram_chart,
    columns=2
)

weather_group
# Out:
# <style>
#   #dp-a3f3e6e7e8674f10b71982f587742210 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="dp-a3f3e6e7e8674f10b71982f587742210" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link rel=&quot;shortcut icon&quot; type=&quot;image/png&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;shortcut icon&quot; sizes=&quot;192x192&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;apple-touch-icon&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
#
# &lt;script src=&quot;https://kit.fontawesome.com/256c714d9a.js&quot;&gt;&lt;/script&gt;
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.5/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.5/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   // analytics config
#   // TODO -- pass these in as props for consistency?
#   window.dpAppRunner = &quot;False&quot; === &quot;True&quot;;
#   window.dpLocal = true;
#     window.dpLocalViewEvent = true;
#     window.dpReportId = &quot;a3f3e6e7e8674f10b71982f587742210&quot;;
#     window.dpAuthorId = &quot;82e136cb011f497b92dc952ca437c34d&quot;;
#
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: left;
#     --dp-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#
#   if (!window.dpAppRunner) {
#       // pass app data via props if in local (static) mode, otherwise this data is fetched from the server
#       window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cGroup columns=\&quot;2\&quot; valign=\&quot;top\&quot;\u003e\u003cPlot type=\&quot;application/vnd.vegalite.v4+json\&quot; responsive=\&quot;true\&quot; scale=\&quot;1.0\&quot; src=\&quot;ref://d105230bfe\&quot;/\u003e\u003cPlot type=\&quot;application/vnd.vegalite.v4+json\&quot; responsive=\&quot;true\&quot; scale=\&quot;1.0\&quot; src=\&quot;ref://6b9e8ef926\&quot;/\u003e\u003cPlot type=\&quot;application/vnd.vegalite.v4+json\&quot; responsive=\&quot;true\&quot; scale=\&quot;1.0\&quot; src=\&quot;ref://d573f5726e\&quot;/\u003e\u003cPlot type=\&quot;application/vnd.vegalite.v4+json\&quot; responsive=\&quot;true\&quot; scale=\&quot;1.0\&quot; src=\&quot;ref://64b62140b8\&quot;/\u003e\u003cPlot type=\&quot;application/vnd.vegalite.v4+json\&quot; responsive=\&quot;true\&quot; scale=\&quot;1.0\&quot; src=\&quot;ref://551795296e\&quot;/\u003e\u003cPlot type=\&quot;application/vnd.vegalite.v4+json\&quot; responsive=\&quot;true\&quot; scale=\&quot;1.0\&quot; src=\&quot;ref://2815b1eca7\&quot;/\u003e\u003c/Group\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {&quot;d105230bfe&quot;: {&quot;src&quot;: &quot;data:application/vnd.vegalite.v4+json;base64,...&quot;, &quot;hash&quot;: &quot;d105230bfe&quot;, &quot;size&quot;: 3908, &quot;mime&quot;: &quot;application/vnd.vegalite.v4+json&quot;}, &quot;6b9e8ef926&quot;: {&quot;src&quot;: &quot;data:application/vnd.vegalite.v4+json;base64,...&quot;, &quot;hash&quot;: &quot;6b9e8ef926&quot;, &quot;size&quot;: 3068, &quot;mime&quot;: &quot;application/vnd.vegalite.v4+json&quot;}, &quot;d573f5726e&quot;: {&quot;src&quot;: &quot;data:application/vnd.vegalite.v4+json;base64,...&quot;, &quot;hash&quot;: &quot;d573f5726e&quot;, &quot;size&quot;: 3948, &quot;mime&quot;: &quot;application/vnd.vegalite.v4+json&quot;}, &quot;64b62140b8&quot;: {&quot;src&quot;: &quot;data:application/vnd.vegalite.v4+json;base64,...&quot;, &quot;hash&quot;: &quot;64b62140b8&quot;, &quot;size&quot;: 2500, &quot;mime&quot;: &quot;application/vnd.vegalite.v4+json&quot;}, &quot;551795296e&quot;: {&quot;src&quot;: &quot;data:application/vnd.vegalite.v4+json;base64,...&quot;, &quot;hash&quot;: &quot;551795296e&quot;, &quot;size&quot;: 3020, &quot;mime&quot;: &quot;application/vnd.vegalite.v4+json&quot;}, &quot;2815b1eca7&quot;: {&quot;src&quot;: &quot;data:application/vnd.vegalite.v4+json;base64,...&quot;, &quot;hash&quot;: &quot;2815b1eca7&quot;, &quot;size&quot;: 3016, &quot;mime&quot;: &quot;application/vnd.vegalite.v4+json&quot;}}} }};
#   }
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://datapane-cdn.com/v0.16.5/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://datapane-cdn.com/v0.16.5/assets/iframeResizer.contentWindow.min.js&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://datapane-cdn.com/v0.16.5/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#dp-a3f3e6e7e8674f10b71982f587742210");
# </script>

# %%
report = dp.Blocks(
    bfro_map,
    report_classification_group,
    reports_per_year_chart,
    sightings_by_state_chart,
    report_seasons_group,
    weather_group
)

dp.save_report(report, "test.html")
# Out:
# App saved to ./test.html
